# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # python 的安装
# 1. `python`版本选择`3.13`
# ## windows
# ```PowerShell
# scoop install miniconda3
# conda create -n py313 python=3.13
# ```
#
# # 配置 Visual Studio Code 环境
#
# ## python 安装
# 1. python 版本选择3.13
# ```bash
# conda create -n py313 python=3.13
# ```
#
#
# ## 使用 uv 管理
# ```bash
# conda activate py313
# # 在项目的目录下
# uv venv
# uv pip install requests
# uv pip install duckdb, pandas
# uv pip install jupyter, ipykernel
# uv pip install openai
# ```
# ## 配置 git
# ### .gitignore
# ```bash
# .venv/
# env/
# ```
#
# # 支持`ipynb` 导出`pdf`
# ## 安装字体（适配中文与标准科技文档）
# ## 安装 LaTeX 编译环境
# 1. 安装 MiKTeX
# 2. 安装已下宏包
# - xeCJK：中文支持
# - fontspec：字体配置
# - tocloft：目录美化
# - hyperref：目录跳转支持
# ## 配置`nbconvert`模板
# ### 需要自定义一个`latex-chinese` 模板
# 1. 目录结构建议：
# ```bash
# .your_venv/
# └── share/
#     └── jupyter/
#         └── nbconvert/
#             └── templates/
#                 └── latex-chinese/
#                     ├── index.tex.j2
#                     └── conf.json（可选）
# ```
#
# ## 配置`index.tex.j2`模板的核心内容：
# 主要通过配置`index.tex.j2`来完成定制化的`pdf`输出。
#
# ### Day1：实现基本的中文输出
# ```jinja2
# ((*- extends 'base.tex.j2' -*))
#
# ((* block docclass *))
# \documentclass[UTF8]{ctexart}
# ((* endblock docclass *))
#
# ((* block packages *))
# ((( super() )))
# \usepackage{fontspec}
# \setCJKmainfont{SimSun}
# \setmonofont{Consolas}
# ((* endblock packages *))
# ```
# ### Day2: 实现目录的能力
# ```Jinja2
# ((*- extends 'base.tex.j2' -*))
#
# %----------------------------------------
# % 中文文档类 + 支持科技论文规范
# %----------------------------------------
# ((* block docclass *))
# \documentclass[UTF8]{ctexart}
# ((* endblock docclass *))
#
# ((* block packages *))
# ((( super() )))
# \usepackage{fontspec}
# \setCJKmainfont{SimSun}
# \setmonofont{Consolas}
# ((* endblock packages *))
#
#
# ((* block commands *))
#
# \usepackage{xcolor}
# \usepackage{etoolbox}
# \usepackage{titlesec}
# \usepackage{tocloft}
# \usepackage{titletoc}
#
# % 设置链接颜色黑色
# \definecolor{linkcolor}{rgb}{0,0,0}
# \definecolor{urlcolor}{rgb}{0,0,0}
# \definecolor{citecolor}{rgb}{0,0,0}
# \hypersetup{
#   colorlinks=true,
#   linkcolor=linkcolor,
#   urlcolor=urlcolor,
#   citecolor=citecolor,
# }
#
# % 清除标题染色
# \makeatletter
# \patchcmd{\@sect}{\color{linkcolor}}{}{}{}
# \makeatother
#
# % 一级标题样式
# \titleformat{\section}
#   {\normalfont\bfseries\color{black}\Large}
#   {\thesection}{1em}{}
# \titlespacing{\section}{0pt}{1.0ex plus .2ex minus .2ex}{0.5ex plus .1ex}
#
# % 加粗目录条目数字
# \renewcommand{\cftsecfont}{\bfseries}
# \renewcommand{\cftsecpagefont}{\bfseries}
# % \renewcommand{\cftsecleader}{\cftdotfill{\cftdotsep}}
#
# % 目录标题：蓝色、大字号、不居中
# \renewcommand{\contentsname}{\textcolor{blue}{\bfseries 目录}\\[1.0ex]}
#
# % 目录标题与目录条目之间增加垂直间隙
# \makeatletter
# \patchcmd{\tableofcontents}{\@starttoc{toc}}{%
#   \vspace{1em}\@starttoc{toc}}{}{}
# \makeatother
#
# ((* endblock commands *))
#
# %----------------------------------------
# % 标题元信息
# %----------------------------------------
# ((* block title *))
# \title{ {{ resources.metadata.title | default("无标题文档") }} }
# \author{ {{ resources.metadata.authors | join(", ") | default("无名作者") }} }
# \date{ {{ resources.metadata.date | default("编译日期：\today") }} }
# \date{{{{ resources.metadata.date | default("编译日期：\today") }}}}
# ((* endblock title *))
#
# %----------------------------------------
# % 启用标题 + 目录页
# %----------------------------------------
# ((* block maketitle *))
# \maketitle
# \newpage
# \tableofcontents
# \newpage
# ((* endblock maketitle *))
# ```
# ### Day3: 实现对元数据的读取，比如标题
# ```Jinja2
# ((*- extends 'base.tex.j2' -*))
#
# %----------------------------------------
# % 中文文档类 + 支持科技论文规范
# %----------------------------------------
# ((* block docclass *))
# \documentclass[UTF8]{ctexart}
# ((* endblock docclass *))
#
# ((* block packages *))
# ((( super() )))
# \usepackage{fontspec}
# \setCJKmainfont{SimHei}
# \setmonofont{Consolas}
# ((* endblock packages *))
#
#
# ((* block commands *))
#
# \usepackage{xcolor}
# \usepackage{etoolbox}
# \usepackage{titlesec}
# \usepackage{tocloft}
# \usepackage{titletoc}
#
# % 设置链接颜色黑色
# \definecolor{linkcolor}{rgb}{0,0,0}
# \definecolor{urlcolor}{rgb}{0,0,0}
# \definecolor{citecolor}{rgb}{0,0,0}
# \definecolor{BLUE}{rgb}{0,0,1}
# \hypersetup{
#   colorlinks=true,
#   linkcolor=linkcolor,
#   urlcolor=urlcolor,
#   citecolor=citecolor,
# }
#
# % 清除标题染色
# \makeatletter
# \patchcmd{\@sect}{\color{linkcolor}}{}{}{}
# \makeatother
#
# % 一级标题样式
# \titleformat{\section}
#   {\normalfont\bfseries\color{black}\Large}
#   {\thesection}{1em}{}
# \titlespacing{\section}{0pt}{1.0ex plus .2ex minus .2ex}{0.5ex plus .1ex}
#
# % 加粗目录条目数字
# \renewcommand{\cftsecfont}{\bfseries}
# \renewcommand{\cftsecpagefont}{\bfseries}
# % \renewcommand{\cftsecleader}{\cftdotfill{\cftdotsep}}
#
# % 目录标题：蓝色、大字号、不居中
# \renewcommand{\contentsname}{\textcolor{blue}{\bfseries 目录}\\[1.0ex]}
#
# % 目录标题与目录条目之间增加垂直间隙
# \makeatletter
# \patchcmd{\tableofcontents}{\@starttoc{toc}}{%
#   \vspace{1em}\@starttoc{toc}}{}{}
# \makeatother
#
# ((* endblock commands *))
#
# %----------------------------------------
# % 标题元信息
# %----------------------------------------
# ((* block preamble *))
# \title{{{{ resources.metadata.title | default("未命名文档") }}}}
# \author{{{{ resources.metadata.authors | join(', ') | default("作者") }}}}
# \date{{{{ resources.metadata.date | default("\\today") }}}}
# ((* endblock preamble *))
#
# %----------------------------------------
# % 启用标题 + 目录页
# %----------------------------------------
# ((* block maketitle *))
# \maketitle
# \newpage
# \tableofcontents
# \newpage
# ((* endblock maketitle *))
# ```
#
# ### Day4: 实现在`codecell`中，对代码块灰底方框的显示，并增加行号
# ```Jinja2
# ((*- extends 'base.tex.j2' -*))
#
# %----------------------------------------
# % 中文文档类 + 支持科技论文规范
# %----------------------------------------
# ((* block docclass *))
# \documentclass[UTF8]{ctexart}
# ((* endblock docclass *))
#
# ((* block packages *))
# ((( super() )))
# \usepackage{fontspec}
# \setCJKmainfont{SimHei}
# \setmonofont{Consolas}
# ((* endblock packages *))
#
#
# ((* block commands *))
#
# \usepackage{xcolor}
# \usepackage{etoolbox}
# \usepackage{titlesec}
# \usepackage{tocloft}
# \usepackage{titletoc}
# \usepackage[most]{tcolorbox}
# \usepackage{fancyvrb}
# \usepackage{color}
# \usepackage{fvextra}  % 可选，支持 verbatim 内缩进与分页
# \usepackage{listings}
# \tcbuselibrary{listings, breakable}
#
# \definecolor{codebg}{RGB}{248,248,248}
# \definecolor{codeframe}{RGB}{180,180,180}
#
# \tcbset{listing engine=listings}
#
# \newtcblisting{pycodecell}{
#   colback=codebg,
#   colframe=codeframe,
#   boxrule=0.4pt,
#   arc=2pt,
#   outer arc=2pt,
#   sharp corners,
#   boxsep=3pt,
#   enhanced,
#   left=2pt,
#   right=2pt,
#   top=3pt,
#   bottom=2pt,
#   breakable,
#   listing only,
#   listing options={
#     basicstyle=\ttfamily\small,        % 改为 small 提高可读性
#     numbers=left,
#     numberstyle=\small\color{gray},
#     numbersep=8pt,
#     xleftmargin=1.8em,                 % 保证数字和代码对齐
#     frame=none,
#     tabsize=4,
#     breaklines=true
#   }
# }
#
#
# % 设置链接颜色黑色
# \definecolor{linkcolor}{rgb}{0,0,0}
# \definecolor{urlcolor}{rgb}{0,0,0}
# \definecolor{citecolor}{rgb}{0,0,0}
# \definecolor{BLUE}{rgb}{0,0,1}
# \definecolor{codegray}{rgb}{0.95,0.95,0.95}
#
# \hypersetup{
#   colorlinks=true,
#   linkcolor=linkcolor,
#   urlcolor=urlcolor,
#   citecolor=citecolor,
# }
#
# % 清除标题染色
# \makeatletter
# \patchcmd{\@sect}{\color{linkcolor}}{}{}{}
# \makeatother
#
# % 一级标题样式
# \titleformat{\section}
#   {\normalfont\bfseries\color{black}\Large}
#   {\thesection}{1em}{}
# \titlespacing{\section}{0pt}{1.0ex plus .2ex minus .2ex}{0.5ex plus .1ex}
#
# % 加粗目录条目数字
# \renewcommand{\cftsecfont}{\bfseries}
# \renewcommand{\cftsecpagefont}{\bfseries}
# % \renewcommand{\cftsecleader}{\cftdotfill{\cftdotsep}}
#
# % 目录标题：蓝色、大字号、不居中
# \renewcommand{\contentsname}{\textcolor{blue}{\bfseries 目录}\\[1.0ex]}
#
# % 目录标题与目录条目之间增加垂直间隙
# \makeatletter
# \patchcmd{\tableofcontents}{\@starttoc{toc}}{%
#   \vspace{1em}\@starttoc{toc}}{}{}
# \makeatother
#
# ((* endblock commands *))
#
# %----------------------------------------
# % 标题元信息
# %----------------------------------------
# ((* block preamble *))
# \title{{{{ resources.metadata.title | default("未命名文档") }}}}
# \author{{{{ resources.metadata.authors | join(', ') | default("作者") }}}}
# \date{{{{ resources.metadata.date | default("\\today") }}}}
# ((* endblock preamble *))
#
# ((* block codecell *))
# \begin{pycodecell}
# ((( cell.source | escape_latex )))
# \end{pycodecell}
# ((* endblock codecell *))
#
# %----------------------------------------
# % 启用标题 + 目录页
# %----------------------------------------
# ((* block maketitle *))
# \maketitle
# \newpage
# \tableofcontents
# \newpage
# ((* endblock maketitle *))
# ```
# ### Day5: 实现在`codecell`中，对`python`代码的语法高亮
# ```Jinja2
# ((*- extends 'base.tex.j2' -*))
#
# %----------------------------------------
# % 中文文档类 + 支持科技论文规范
# %----------------------------------------
# ((* block docclass *))
# \documentclass[UTF8]{ctexart}
# ((* endblock docclass *))
#
# ((* block packages *))
# ((( super() )))
# \usepackage{fontspec}
# \setCJKmainfont{SimHei}
# \setmonofont{Consolas}
# ((* endblock packages *))
#
#
# ((* block commands *))
#
# \usepackage{xcolor}
# \usepackage{etoolbox}
# \usepackage{titlesec}
# \usepackage{tocloft}
# \usepackage{titletoc}
# \usepackage[most]{tcolorbox}
# \usepackage{fvextra}  % 可选，支持 verbatim 内缩进与分页
# \usepackage{listings}
# \tcbuselibrary{listings, breakable}
#
# \definecolor{codebg}{RGB}{248,248,248}
# % \definecolor{codeframe}{RGB}{180,180,180}
# \definecolor{codeframe}{gray}{0.6}
#
# \tcbset{listing engine=listings}
#
# \newtcblisting{pycodecell}{
#   colback=codebg,
#   colframe=codeframe,
#   boxrule=0.6pt,
#   arc=0pt,
#   outer arc=2pt,
#   sharp corners,
#   boxsep=3pt,
#   enhanced,
#   left=2pt,
#   right=2pt,
#   top=3pt,
#   bottom=4pt,
#   breakable,
#   listing only,
#   listing options={
#     language=Python,
#     basicstyle=\ttfamily\small,
#     keywordstyle=\color{blue}\bfseries,
#     commentstyle=\color{gray},
#     stringstyle=\color{green!60!black},
#     numbers=left,
#     numberstyle=\scriptsize\color{gray},
#     numbersep=8pt,
#     xleftmargin=1.8em,
#     frame=none,
#     tabsize=4,
#     breaklines=true,
#     showstringspaces=false
#   }
# }
#
#
# % 设置链接颜色黑色
# \definecolor{linkcolor}{rgb}{0,0,0}
# \definecolor{urlcolor}{rgb}{0,0,0}
# \definecolor{citecolor}{rgb}{0,0,0}
# \definecolor{BLUE}{rgb}{0,0,1}
# \definecolor{codegray}{rgb}{0.95,0.95,0.95}
#
# \hypersetup{
#   colorlinks=true,
#   linkcolor=linkcolor,
#   urlcolor=urlcolor,
#   citecolor=citecolor,
# }
#
# % 清除标题染色
# \makeatletter
# \patchcmd{\@sect}{\color{linkcolor}}{}{}{}
# \makeatother
#
# % 一级标题样式
# \titleformat{\section}
#   {\normalfont\bfseries\color{black}\Large}
#   {\thesection}{1em}{}
# \titlespacing{\section}{0pt}{1.0ex plus .2ex minus .2ex}{0.5ex plus .1ex}
#
# % 加粗目录条目数字
# \renewcommand{\cftsecfont}{\bfseries}
# \renewcommand{\cftsecpagefont}{\bfseries}
# % \renewcommand{\cftsecleader}{\cftdotfill{\cftdotsep}}
#
# % 目录标题：蓝色、大字号、不居中
# \renewcommand{\contentsname}{\textcolor{blue}{\bfseries 目录}\\[1.0ex]}
#
# % 目录标题与目录条目之间增加垂直间隙
# \makeatletter
# \patchcmd{\tableofcontents}{\@starttoc{toc}}{%
#   \vspace{1em}\@starttoc{toc}}{}{}
# \makeatother
#
# ((* endblock commands *))
#
# %----------------------------------------
# % 标题元信息
# %----------------------------------------
# ((* block preamble *))
# \title{{{{ resources.metadata.title | default("未命名文档") }}}}
# \author{{{{ resources.metadata.authors | join(', ') | default("作者") }}}}
# \date{{{{ resources.metadata.date | default("\\today") }}}}
# ((* endblock preamble *))
#
# ((* block codecell *))
# \begin{pycodecell}
# ((( cell.source | escape_latex )))
# \end{pycodecell}
# ((* endblock codecell *))
#
# %----------------------------------------
# % 启用标题 + 目录页
# %----------------------------------------
# ((* block maketitle *))
# \maketitle
# \newpage
# \tableofcontents
# \newpage
# ((* endblock maketitle *))
# ```
# ### Day6: 实现对`markdown`的块状输出

# %%
print("Hello Python")
# Out:
# Hello Python
